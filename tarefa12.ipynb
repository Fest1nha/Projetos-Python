# %%
# Importing standard Qiskit libraries
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_histogram, plot_bloch_multivector, visualize_transition, circuit_drawer
import numpy as np
from ibm_quantum_widgets import *
from qiskit_aer import AerSimulator
from qiskit.quantum_info import Statevector, random_statevector
backend = AerSimulator()

# qiskit-ibmq-provider has been deprecated.
# Please see the Migration Guides in https://ibm.biz/provider_migration_guide for more detail.
from qiskit_ibm_runtime import QiskitRuntimeService, Sampler, Estimator, Session, Options

# Loading your IBM Quantum account(s)
service = QiskitRuntimeService(channel="ibm_quantum")
# Out:
# qiskit_runtime_service.__init__:INFO:2024-04-09 14:02:26,073: Default instance: ibm-q/open/main

# %%
# Sorteando ângulos aleatórios para as rotações
theta_x = np.random.uniform(0, 2*np.pi)
theta_y = np.random.uniform(0, 2*np.pi)
theta_z = np.random.uniform(0, 2*np.pi)

# Calculando o vetor de Bloch do estado aleatório
vetor = [np.sin(theta_y)*np.cos(theta_x), np.sin(theta_y)*np.sin(theta_x), np.cos(theta_y)]

# Plotando o vetor de Bloch
plot_bloch_vector(vetor)

# %%
# Definindo o circuito quântico com 1 q-bit
qc = QuantumCircuit(1)

# Aplicando rotação em torno do eixo x
qc.rx(theta_x, 0)

# Aplicando rotação em torno do eixo y
qc.ry(theta_y, 0)

# Aplicando rotação em torno do eixo z
qc.rz(theta_z, 0)

qc.save_statevector()

# Simulação do circuito quântico
job = backend.run(qc)
result = job.result()
vetor = result.get_statevector()

# Plotando o estado no bloch sphere
plot_bloch_multivector(vetor)

# %%
#Nao conhicidem
